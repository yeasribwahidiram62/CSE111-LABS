# %%
import math
class Circle:
    def __init__(self,radius):
        self.__radius = radius
        self.__pi = math.pi
    def getRadius(self):
        return self.__radius
    def setRadius (self,radius):
        self.__radius = radius
    def area (self):
        return float(self.__pi*(self.__radius)**2)
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())


c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
class Triangle:
    def __init__(self,base,height):
        self.__base = base
        self.__height = height
    def getBase(self):
        return self.__base
    def getHeight(self):
        return self.__height
    def setBase(self,base):
        self.__base = base
    def setHeight(self,height):
        self.__height = height
    def area(self):
        return 0.5*self.__base*self.__height
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
class Team:
    def __init__(self, c = None):
        self.__c = c
        self.__player = []
    def setName(self,c):
        self.__c = c
    def addPlayer(self,p):
        self.__player.append(p.name)
    def printDetail(self):
        print("=====================")
        print(f"Team:{self.__c}")
        print("List of Players:")
        print(self.__player)
        print("=====================")
class Player:
    def __init__(self,name):
        self.name = name
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:Bangladesh
# List of Players:
# ['Mashrafi', 'Tamim']
# ...
# Team:Australia
# List of Players:
# ['Ponting', 'Lee']
# ...

# %%
class Spaceship:
  def __init__(self,sname,scap):
    self.sname=sname
    self.scap=scap
    self.li=[]
    self.count=0

  def load_cargo(self,name):
    self.name=name
    remcap=self.scap-self.count
    if remcap>self.name.cw():
      self.count+=self.name.cw()
      self.li.append(self.name.cname())
    elif remcap<self.name.cw():
      print(f'Warning: Unable to load {self.name.cname()} inside {self.sname}. Exceeds capacity by {self.name.cw()-remcap}.')
  def display_details(self):
    print(f'Spaceship Name: {self.sname}')
    print(f'Capacity: {self.scap}')
    print(f'Current Cargo Weight:{self.count}')
    print(f'Cargo:{self.li}')
class Cargo:
  def __init__(self,cname,cweight):
    self.__cname=cname
    self.__cweight=cweight
  def cname(self):
    return self.__cname
  def cw(self):
    return self.__cweight
falcon = Spaceship("Falcon", 50000)
apollo = Spaceship("Apollo", 100000)
enterprise = Spaceship("Enterprise", 220000)
print("1.===================================")
# Creating cargo
gold = Cargo("Gold", 20000)
platinum = Cargo("Platinum", 25000)
dilithium = Cargo("Dilithium", 50000)
trilithium = Cargo("Trilithium", 70000)
neutronium = Cargo("Neutronium", 80000)
print("2.===================================")
# Loading cargo onto spaceships
falcon.load_cargo(gold)
falcon.load_cargo(platinum)
falcon.display_details()
print("3.===================================")
apollo.load_cargo(gold)  # Apollo will not reach its total capacity
apollo.display_details()
print("4.===================================")
falcon.load_cargo(neutronium)  # This should exceed Falcon's capacity
print("5.===================================")
enterprise.load_cargo(dilithium)
enterprise.load_cargo(trilithium)
enterprise.load_cargo(neutronium)  # This should not exceed Enterprise's capacity
enterprise.display_details()
# Out:
# 1.===================================
# 2.===================================
# Spaceship Name: Falcon
# Capacity: 50000
# Current Cargo Weight:45000
# Cargo:['Gold', 'Platinum']
# 3.===================================
# Spaceship Name: Apollo
# Capacity: 100000
# Current Cargo Weight:20000
# Cargo:['Gold']
# 4.===================================
# ...
# 5.===================================
# Spaceship Name: Enterprise
# Capacity: 220000
# Current Cargo Weight:200000
# Cargo:['Dilithium', 'Trilithium', 'Neutronium']

# %%
class BracuStudent:
    def __init__(self,name,location):
        self.name = name
        self.location = location
        self.p = False
    def get_pass(self):
        self.p == True
        print
    def show_details(self):
        print (f"Student Name: {self.name}")
        print(f"Lives in {self.location}")
        print(f"Have bus pass?{self.p}")
class BracuBus:
    def __init__(self,destination,capacity = 2):
        self.__d = destination
        self.__c = capacity
        self.lst = []
    def board(self, *x):
        for i in x:
            if len(self.lst) < self.__c :
                if i.location == self.__d and i.location == i.p :
                    self.lst.append (i.name)
                    print(f"{i.name} boarded the bus.")
                else:
                    print(f"{i.name} got on the wrong bus.")
            else:
                print(f"Bus is full!")
    def show_details(self):
        print(f"Bus Route: {self.__d}")
        print(f"Passengers Count: {len(self.lst)} (Max: {self.__c})")
        print(f"Passengers On Board: {self.lst}")

st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have bus pass?False
# Student Name: Shanto
# Lives in Motijheel
# Have bus pass?False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have bus pass?False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have bus pass?False
# Student Name: Taskin
# Lives in Mirpur
# Have bus pass?False
# 6===========================
# 7===========================
# Afif got on the wrong bus.
# Shanto got on the wrong bus.
# 8===========================
# Student Name: Afif
# Lives in Mirpur
# Have bus pass?False
# Student Name: Shanto
# Lives in Motijheel
# Have bus pass?False
# 9===========================
# Afif got on the wrong bus.
# Shanto got on the wrong bus.
# ...

# %%
#mine
class Spaceship:
  def __init__(self,name,capacity):
    self.name=name
    self.capacity=capacity
    self.lst=[]
    self.count=0
  def load_cargo(self, n):
    self.n = n
    x = self.capacity - self.count
    if x > self.n.c_cpc():
        self.count += self.n.c_cpc()
        self.lst.append(self.n.c_name())
    elif x < self.n.c_cpc():
        print("Warning: Unable to load", self.n.c_name(), "inside", self.name,". Exceeds capacity by", (self.n.c_cpc()-x),".")
  def display_details(self):
        print("Spaceship Name:", self.name)
        print("Capacity:", self.capacity)
        print("Current Cargo Weight:",self.count)
        print("Cargo:",self.lst)




class Cargo:
    def __init__(self,nm,cpc):
        self.__nm = nm
        self.__cpc = cpc
    def c_name(self):
        return self.__nm
    def c_cpc(self):
        return self.__cpc
falcon = Spaceship("Falcon", 50000)
apollo = Spaceship("Apollo", 100000)
enterprise = Spaceship("Enterprise", 220000)
print("1.===================================")
# Creating cargo
gold = Cargo("Gold", 20000)
platinum = Cargo("Platinum", 25000)
dilithium = Cargo("Dilithium", 50000)
trilithium = Cargo("Trilithium", 70000)
neutronium = Cargo("Neutronium", 80000)
print("2.===================================")
# Loading cargo onto spaceships
falcon.load_cargo(gold)
falcon.load_cargo(platinum)
falcon.display_details()
print("3.===================================")
apollo.load_cargo(gold)  # Apollo will not reach its total capacity
apollo.display_details()
print("4.===================================")
falcon.load_cargo(neutronium)  # This should exceed Falcon's capacity
print("5.===================================")
enterprise.load_cargo(dilithium)
enterprise.load_cargo(trilithium)
enterprise.load_cargo(neutronium)  # This should not exceed Enterprise's capacity
enterprise.display_details()
# Out:
# 1.===================================
# 2.===================================
# Spaceship Name: Falcon
# Capacity: 50000
# Current Cargo Weight: 45000
# Cargo: ['Gold', 'Platinum']
# 3.===================================
# Spaceship Name: Apollo
# Capacity: 100000
# Current Cargo Weight: 20000
# Cargo: ['Gold']
# 4.===================================
# ...
# 5.===================================
# Spaceship Name: Enterprise
# Capacity: 220000
# Current Cargo Weight: 200000
# Cargo: ['Dilithium', 'Trilithium', 'Neutronium']

# %%
class BracuStudent:
    def __init__(self, name, home):
        self.name = name
        self.home = home
        self.bus_pass = False

    def show_details(self):
        print(f"Student Name: {self.name}")
        print(f"Lives in {self.home}")
        print(f"Have Bus Pass? {self.bus_pass}")

    def get_pass(self):
        self.bus_pass = True
        print(f"{self.name} got the bus pass.")

class BracuBus:
    def __init__(self, route, max_capacity=2):
        self.route = route
        self.max_capacity = max_capacity
        self.passengers = []

    def show_details(self):
        print(f"Bus Route: {self.route}")
        print(f"Passengers Count: {len(self.passengers)} (Max: {self.max_capacity})")
        print(f"Passengers On Board: {self.passengers}")

    def board(self, *students):
        for student in students:
            if len(self.passengers) < self.max_capacity:
                if student.home == self.route and student.bus_pass:
                    self.passengers.append(student.name)
                    print(f"{student.name} boarded the bus.")
                else:
                    print(f"{student.name} got on the wrong bus!")
            else:
                print("Bus is full!")

# Driver Code
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# Shanto got the bus pass.
# Taskin got the bus pass.
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# 7===========================
# Afif got on the wrong bus!
# 8===========================
# Afif got the bus pass.
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# ...

# %%
class Library:
  def __init__(self, name, books_availability):
    self.name = name
    self.borrower_details = {}
    self.books_availability = books_availability

  def details(self):
    print(f"{self.name} Library details")
    print(f"Borrower details:\n{self.borrower_details}")
    print(f"Books availability:\n{self.books_availability}")

class Reader:
  def __init__(self, reader_name):
    self.reader_name = reader_name
    self.book_count = 0
    self.borrowed_books = {}

  def borrow(self, library_name, *books):
    for book in books:
      if book in library_name.books_availability:
        if library_name.books_availability[book] != 0:
          if self.book_count < 5:
            if book in self.borrowed_books:
                self.borrowed_books[book] += 1
            else:
                self.borrowed_books[book] = 1
            print(f"{book} book is borrowed successfully.")
            self.book_count += 1
            library_name.borrower_details[self.reader_name] = self.book_count
            library_name.books_availability[book] -= 1
          else:
            print("You cannot borrow more than 5 books.")
        else:
          print(f"{book} books are not available at the moment.")


  def readerInfo(self, book_type = None):
    if book_type == None:
      print(f"{self.reader_name}, you have {(self.book_count)} book(s) with you.")
      for book, quantity in self.borrowed_books.items():
        print(f"Books on {book}: {quantity}")
    else:
      print(f"{self.reader_name}, you have {self.borrowed_books[book_type]} {book_type} book(s) with you.")



L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details:
# {}
# Books availability:
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed successfully.
# Fiction book is borrowed successfully.
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 2----------------------
# Politics book is borrowed successfully.
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 5 book(s) with you.
# Books on Arts: 1
# Books on Fiction: 2
# Books on Politics: 2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details:
# {'Aladdin': 5}
# Books availability:
# {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics books are not available at the moment.
# Poetry book is borrowed successfully.
# 7----------------------
# ...

# %%
class BracuStudent:
    def __init__(self, name, home):
        self.name = name
        self.home = home
        self.bus_pass = False

    def get_pass(self):
        self.bus_pass = True

    def show_details(self):
        print(f"Student Name: {self.name}")
        print(f"Lives in {self.home}")
        print(f"Has Bus Pass? {'Yes' if self.bus_pass else 'No'}")


class BracuBus:
    def __init__(self, route, max_capacity=2):
        self.route = route
        self.max_capacity = max_capacity
        self.passenger_list = []

    def board(self, *passengers):
        if not passengers:
            print("No passengers!")
            return

        for passenger in passengers:
            if not isinstance(passenger, BracuStudent):
                print("Invalid passenger.")
                continue

            if not passenger.bus_pass:
                print(f"You don't have a bus pass!")
            elif passenger.home != self.route:
                print(f"You got on the wrong bus!")
            elif len(self.passenger_list) >= self.max_capacity:
                print("Bus is full!")
                break
            elif passenger in self.passenger_list:
                print(f"{passenger.name} has already boarded the bus.")
            else:
                self.passenger_list.append(passenger)
                print(f"{passenger.name} boarded the bus.")

    def show_details(self):
        print(f"Bus Route: {self.route}")
        print(f"Passenger Count: {len(self.passenger_list)} (Max: {self.max_capacity})")
        print("Passengers on Board:", list(passenger.name for passenger in self.passenger_list))



# Driver Code
st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.display_details()
st2.display_details()
print("2===========================")
st3.display_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.acquire_bus_pass()
st3.acquire_bus_pass()
print("5===========================")
st2.display_details()
st3.display_details()
print("6===========================")
bus1.board_passengers()
print("7===========================")
bus1.board_passengers(st1, st2)
print("8===========================")
st1.acquire_bus_pass()
st2.home = "Mirpur"
st1.display_details()
st2.display_details()
print("9===========================")
bus1.board_passengers(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-1bcf699dff2a> in <cell line: 57>()
#      55 st2 = BracuStudent("Shanto", "Motijheel")
#      56 st3 = BracuStudent("Taskin", "Mirpur")
# ---> 57 st1.display_details()
#      58 st2.display_details()
#      59 print("2===========================")
#
# AttributeError: 'BracuStudent' object has no attribute 'display_details'
